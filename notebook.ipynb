# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
import re
from tqdm import tqdm
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForTokenClassification, TrainingArguments, Trainer, pipeline 
import torch

# %%
url_list = pd.read_csv(r'C:\Users\healk\Desktop\bro2\URL_list.csv')['max(page)'].tolist()

texts = []
def fetch_product_data(url_list):
    for url in url_list:  # Можно ограничиться 100 URL
        try:
            resp = requests.get(url, timeout=10)
            if resp.status_code == 200:
                soup = BeautifulSoup(resp.content, 'html.parser')
                [s.decompose() for s in soup(["script", "style", "noscript"])]
                text = soup.get_text(separator='\n', strip=True)
                texts.append({'url': url, 'text': text})
        except Exception as e:
            print(f"Error with {url}: {e}")
    unmarked = pd.DataFrame(texts)
    unmarked.to_csv('web_texts_for_ner.csv', index=False)
    return unmarked

furniture_products = [
    'sofa', 'couch', 'settee', 'chair', 'table', 'bed',
    'desk', 'dresser', 'armchair', 'recliner', 'accent chair',
    'side table', 'bedframe', 'headboard', 'mattress', 'cupboard',
    'wardrobe', 'bookshelf', 'ottoman', 'coffee table', 'nightstand',
    'dining table', 'sideboard', 'cabinet', 'entertainment center',
    'futon', 'bench', 'stool', 'chaise lounge', 'loveseat', 'lights', 'sofa', 'sofas',
    'ceiling', 'shelf', 'lamp', 'children', 'kids', 'furniture', 'tv', 'stand', 'armchair',
    'decor', 'decoration', 'accessories', 'furnishing', 'interior', 'outdoor', 'indoor',
    'kitchen', 'office', 'living room', 'bedroom', 'dining room', 'hallway', 'storage',
    'reception', 'workspace', 'patio', 'balcony', 'garden', 'porch', 'veranda', 'entryway', 'basement', 'attic'
    ]

def extract_product_candidates(text):
    pattern = r'\b([A-ZА-Я][\w\-]+(?: [A-ZА-Я][\w\-]+){0,4})\b'
    candidates = []
    for line in text.split('\n'):
        matches = re.findall(pattern, line)
        candidates.extend(matches)

    filtered = []
    for c in set(candidates):
        c_lower = c.lower()
        for keyword in furniture_products:
            if keyword in c_lower:
                filtered.append(c)
                break
    return filtered

# %%
#unmarked = fetch_product_data(url_list)
unmarked = pd.read_csv('web_texts_for_ner.csv')
unmarked = unmarked.dropna(subset=['text'])
unmarked_list = unmarked['text'].values
texts_array = unmarked_list[:200]  # Ограничим количество текстов для обучения
texts_array_eval = unmarked_list[200:]

# %%
unmarked.head()
# Out:
#                                                  url  \
# 0  https://www.factorybuys.com.au/products/euro-t...
# 1    https://dunlin.com.au/products/beadlight-cirrus
# 2  https://themodern.net.au/products/hamar-plant-...
# 3  https://interiorsonline.com.au/products/interi...
# 4   https://livingedge.com.au/products/tables/dining
#
#                                                 text
# 0  Factory Buys 32cm Euro Top Mattress - King\nSk...
# 1  Beadlight Cirrus LED Reading Light\n– Dunlin H...
# 2  Hamar Plant Stand - Ash\n– The Modern\nSkip to...
# 3  Gift Cards | RJ Living\nSkip to content\nEOFY ...
# 4  Dining Tables | Living Edge\nTo continue, plea...

# %%
print(extract_product_candidates(unmarked_list[0]))
# Out:
# ['Hamptons Furniture', 'King Single Mattress', 'Wicker Outdoor', 'Home Furniture', 'White Dining Chairs', 'Kitchen Appliances', 'Queen Bedroom Packages', 'Outdoor Tables', 'Poster Bed Frames', 'Outdoor Settings', 'Velvet Dining Chairs', 'Soft Mattress', 'Velvet Bed Frame', 'Industrial Furniture', 'Outdoor Settings By Size', 'Outdoor Dining', 'Mattresses By Feel', 'Outdoor Furniture', 'Garden', 'Monitor Stands', 'Leather Armchairs', 'Massage Tables', 'Caravan Accessories', 'Poster Bed Frame', 'Kids Sports', 'String Lights', 'Dining Furniture', 'Wooden Bed Base', 'Outdoor Furniture By Style', 'Small Desks', 'Double Bedroom Suite', 'Kids Bedroom Furniture', 'Large Christmas Decor', 'Bunk Beds', 'LED Furniture', 'Queen Headboards', 'Bar Stools', 'Base With Storage Platform Fabric', 'Gas Lift Beds', 'Ensemble Beds', 'Massage Accessories', 'Black Dining Chairs', 'Storage Furniture', 'Papasan Chairs', 'Futons', 'Outdoor Shades', 'Bouclé Sofas', 'Ensemble Bed Base', 'King Single Bedroom Suites', 'Plastic Stools', 'Mattress', 'Low Bed Frames', 'Gas Lift Bed Frames', 'Outdoor', 'Bed Headboards By Size', 'King Bed Frames', 'Single Bed Linen', 'Double Bedroom Suites', 'Storage', 'Single Mattress Protectors', 'Dining Room Furniture', 'Dining Room', 'Mattress Package', 'Scandi Armchairs', 'Furnishings', 'TV Units', 'Kitchen Sinks', 'Lights', 'King Bedroom Suites', 'Farming Accessories', 'Christmas Inflatables', 'Bed Base', 'Kids Convertible Arm Chairs', 'Bedroom Packages', 'King Dreamz Mattress Protector Luxury', 'Queen Mattresses', 'Fiona Bed Frame Bouclé', 'Kids Furniture', 'Outdoor Recliners', 'Kids Basketball Hoops', 'FREE SHIPPING ON MATTRESSES', 'Double Mattress', 'Arm Chairs', 'Living Room Furniture', 'Table Top Christmas Trees', 'Floor Sofa', 'King Mattress', 'Office Furniture', 'Kids Toys', 'King DreamZ Mattress Protector Topper', 'Single Mattresses', 'Garden Benches', 'Kids Bed Frame', 'Gaming Furniture', 'Camping Chairs', 'Furniture', 'Firm Mattress', 'Living Room', 'Queen Bed Bases', 'Accessories', 'Solar Powered Lights', 'Chair Mats', 'Sofas', 'Medium Firm Mattress', 'King Single Bedroom Packages', 'Kids Chairs', 'Kids', 'Jewellery Cabinets', 'Outdoor Decor', 'Free Shipping Mattress Sale', 'LED Bedroom Packages', 'Bedside Tables', 'Queen Bedroom Suite', 'Kids Outdoor Furniture', 'Kids Play Room', 'Kids Play Sets', 'Cabinets', 'Christmas Lights', 'Bed Frames', 'Outdoor Bar Sets', 'Laundry Storage', 'Kids Bunk Bed', 'Bedroom Furniture', 'Office Accessories', 'Bedding', 'Sofa Covers', 'Outdoor Benches', 'Double Bed Heads', 'King Single Bed Bases', 'Armchairs', 'Ottomans', 'Modern Outdoor Furniture', 'Waterproof Outdoor Furniture', 'Inflatable Trees', 'Single Bedroom Packages', 'Mattress Toppers', 'Fabric Bed Frames', 'Computer Accessories', 'Stand Up Paddle Boards', 'King Bed Heads', 'Outdoor Heating', 'Mattress Size Guide', 'Headboards', 'Velvet Armchairs', 'Leather Bed Frames', 'LED Lights', 'Outdoor Umbrellas', 'Yoga Accessories', 'Linen Bed Frames', 'King Bedroom Suite', 'King Headboards', 'King Bed Bases', 'Garden Ornaments', 'Office Massage Chairs', 'Queen Bed Linen', 'Factory Buys Euro Top Mattress', 'Walnut Furniture', 'Floor Sofas', 'Recliner Chairs', 'Portable Firepits', 'Plush Mattress', 'Outdoor Furniture On Sale', 'Kids Mattresses', 'Coffee Tables', 'Memory Foam Mattress', 'Gold Lights', 'Outdoor Play', 'Beds', 'Double Headboards', 'Scandi Furniture', 'Bed Frame', 'Bouclé Bed Frames', 'Velvet Armchair', 'Kids Table', 'House Bed Frames', 'Kids Bed Frames', 'Bed Frames On Sale', 'Kids Recliner Chairs', 'Kids Inflatable', 'Kitchen', 'Grow Lights', 'Pocket Spring Mattress', 'King Single Bedroom Suite', 'Sit Stand Desks', 'Chloe Bed Frame Metal Platform', 'Bed Headboard', 'Filing Cabinets', 'Corner Desks', 'Baby Change Tables', 'Single Mattress', 'Make Up Storage', 'Laptop Desks', 'Queen Bed Frames', 'Music Stands', 'Scandi Bed Frames', 'Double Mattresses', 'Kids Trampolines', 'Dining Chair', 'Single Bed Frames', 'Metal Be ...

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")
label2id = {'O': 0, 'B-PRODUCT': 1, 'I-PRODUCT': 2}
id2label = {v: k for k, v in label2id.items()}
label_list = ["O", "B-PRODUCT", "I-PRODUCT"]

def clean_and_split(text):
    return re.findall(r'\w+|\$[\d\.]+|\S+', text)

def BIO_label_words(text, product_names):
    words = clean_and_split(text)
    labels = ['O'] * len(words)

    for prod in product_names:
        prod_words = clean_and_split(prod)
        for i in range(len(words) - len(prod_words) + 1):
            if words[i:i+len(prod_words)] == prod_words:
                labels[i] = 'B-PRODUCT'
                for j in range(1, len(prod_words)):
                    labels[i+j] = 'I-PRODUCT'
    return words, labels

def prepare_bio_training_data(texts):
    tokenized_dataset = []

    for text in tqdm(texts, desc="Preparing data"):
        # Step 1: auto-generate product candidates
        product_names = extract_product_candidates(text)

        # Step 2: word-level BIO labeling
        words, labels = BIO_label_words(text, product_names)

        # Step 3: tokenize and align labels
        tokenized = tokenizer(
            words,
            is_split_into_words=True,
            truncation=True,
            padding='max_length',
            max_length=512,
            return_offsets_mapping=False
        )

        word_ids = tokenized.word_ids()
        label_ids = []

        previous_word_idx = None
        for word_idx in word_ids:
            if word_idx is None:
                label_ids.append(-100)
            else:
                label_ids.append(label2id[labels[word_idx]])

        tokenized['labels'] = label_ids
        tokenized_dataset.append(tokenized)

    return tokenized_dataset

# %%
temp1 = BIO_label_words(texts_array[0], extract_product_candidates(texts_array[0]))
print(temp1[0])
print(temp1[1])
# Out:
# ['Factory', 'Buys', '32cm', 'Euro', 'Top', 'Mattress', '-', 'King', 'Skip', 'to', 'content', 'FREE', 'SHIPPING', 'ON', 'MATTRESSES', 'BED', 'FRAMES', 'FROM', '$89', '!', 'FAST', 'SHIPPING', 'AUSTRALIA', 'WIDE', '!', 'Home', 'Furniture', 'Home', 'Furniture', 'Bedroom', 'Furniture', 'Mattresses', 'Living', 'Room', 'Furniture', 'Dining', 'Furniture', 'Office', 'Furniture', 'Storage', 'Furniture', 'Packages', 'Mattresses', 'Mattresses', 'Queen', 'Mattress', 'Queen', 'Mattress', 'Queen', 'Bed', 'Frames', 'Queen', 'Bed', 'Bases', 'Queen', 'Bed', 'Head', 'Queen', 'Bedroom', 'Packages', 'Queen', 'Bedroom', 'Suites', 'Queen', 'Bed', 'Linen', 'Double', 'Mattress', 'Double', 'Mattress', 'Double', 'Bed', 'Frames', 'Double', 'Bed', 'Bases', 'Double', 'Bed', 'Heads', 'Double', 'Bedroom', 'Packages', 'Double', 'Bedroom', 'Suites', 'Double', 'Bed', 'Linen', 'King', 'Mattress', 'King', 'Mattress', 'King', 'Bed', 'Frames', 'King', 'Bed', 'Bases', 'King', 'Bed', 'Heads', 'King', 'Bedroom', 'Packages', 'King', 'Bedroom', 'Suites', 'King', 'Bed', 'Linen', 'Super', 'King', 'Mattress', 'King', 'Single', 'Mattress', 'King', 'Single', 'Mattress', 'King', 'Single', 'Bed', 'Frames', 'King', 'Single', 'Bed', 'Bases', 'King', 'Single', 'Bedroom', 'Packages', 'King', 'Single', 'Bedroom', 'Suites', 'King', 'Single', 'Bed', 'Linen', 'Single', 'Mattress', 'Single', 'Mattress', 'Single', 'Bed', 'Frames', 'Single', 'Bed', 'Bases', 'Single', 'Bedroom', 'Packages', 'Single', 'Bedroom', 'Suites', 'Single', 'Bed', 'Linen', 'Single', 'Mattress', 'Toppers', 'Single', 'Mattress', 'Protectors', 'Super', 'King', 'Mattress', 'Super', 'King', 'Mattress', 'Bed', 'Frames', 'Mattresses', 'Bedding', 'Bedroom', 'Packages', 'Bed', 'Frames', 'Bedroom', 'Packages', 'Bedroom', 'Suites', 'Bedroom', 'Furniture', 'Bedroom', 'Furniture', 'Mattresses', 'Bed', 'Frames', 'Bedroom', 'Packages', 'Bedroom', 'Suites', 'Bedside', 'Tables', 'Bedside', 'Tables', 'Tallboys', 'Storage', 'Furniture', 'Bed', 'Frames', 'Lightings', 'Mattresses', 'Dressing', 'Table', '&', 'Makeup', 'Vanity', 'Bedroom', 'Packages', 'Wardrobes', 'Wardrobes', 'Tallboys', 'Clothes', 'Rack', 'Storage', 'Furniture', 'Bed', 'Frames', 'Lightings', 'Mattresses', 'Dressing', 'Table', '&', 'Makeup', 'Vanity', 'Tallboys', 'Tallboys', 'Bedside', 'Tables', 'Wardrobes', 'Jewellery', 'Cabinets', 'Storage', 'Furniture', 'Dressing', 'Tables', 'Cabinets', 'Shoe', 'Storage', 'Dressing', 'Tables', 'Dressing', 'Tables', 'Arm', 'Chairs', 'Wardrobes', 'Jewellery', 'Cabinets', 'Tallboys', 'Ottomans', 'Shoe', 'Storage', 'Storage', 'Furniture', 'Bed', 'Headboards', 'Bed', 'Headboards', 'Queen', 'Bed', 'Head', 'Double', 'Bed', 'Head', 'King', 'Bed', 'Head', 'Bed', 'Bases', 'Bed', 'Frames', 'Mattresses', 'Bedroom', 'Furniture', 'Ottomans', 'Ottomans', 'Bedside', 'Tables', 'Bed', 'Frames', 'Tallboys', 'Storage', 'Furniture', 'Dressing', 'Tables', 'Rugs', 'Bouclé', 'Ottomans', 'Bouclé', 'Ottomans', 'Bouclé', 'Sofas', 'Bouclé', 'Furniture', 'Bouclé', 'Bed', 'Frames', 'Bed', 'Frames', 'Bed', 'Frames', 'Queen', 'Bed', 'Frames', 'Queen', 'Bed', 'Frames', 'Queen', 'Mattresses', 'Queen', 'Bedroom', 'Packages', 'Queen', 'Bedroom', 'Suites', 'Queen', 'Bed', 'Bases', 'Queen', 'Headboards', 'Bedroom', 'Furniture', 'Mattresses', 'Double', 'Bed', 'Frames', 'Double', 'Bed', 'Frames', 'Double', 'Mattresses', 'Double', 'Bedroom', 'Packages', 'Double', 'Bedroom', 'Suites', 'Double', 'Bed', 'Bases', 'Double', 'Headboards', 'Mattresses', 'Bedroom', 'Furniture', 'King', 'Bed', 'Frames', 'King', 'Bed', 'Frames', 'King', 'Mattresses', 'King', 'Bedroom', 'Packages', 'King', 'Bedroom', 'Suites', 'King', 'Bed', 'Bases', 'King', 'Headboards', 'Mattresses', 'Bedroom', 'Furniture', 'Single', 'Bed', 'Frames', 'Single', 'Bed', 'Frames', 'Single', 'Mattresses', 'Single', 'Bedroom', 'Packages', 'Single', 'Bedroom', 'Suites', 'Single', 'Bed', 'Bases', 'Headboards', 'Mattresses', 'Bedroom', 'Furniture', 'King', 'Single', 'Bed', 'Frames', 'King', 'Single', 'Bed', 'Frames', 'King', ...
# ['O', 'O', 'O', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'O', 'O', 'O', 'O', 'O', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'O', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'O', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'O', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'O', 'O', 'O', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'O', 'O', 'O', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'O', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'O', 'O', 'O', 'O', 'O', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'O', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'O', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'O', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'B-PRODUCT', 'B-PRODUCT', 'I-PRODUCT', 'I-PRODUCT', ...

# %%
tokenized_inputs = prepare_bio_training_data(texts_array)

dataset = Dataset.from_list(tokenized_inputs)
dataset_test = Dataset.from_list(prepare_bio_training_data(texts_array_eval))
# Out:
# Preparing data: 100%|██████████| 5/5 [00:00<00:00,  9.95it/s]
# Preparing data: 0it [00:00, ?it/s]

# %%
import evaluate

seqeval = evaluate.load("seqeval")

def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_labels = [
        [label_list[l] for l in label_row if l != -100]
        for label_row in labels
    ]
    true_predictions = [
        [label_list[p] for p, l in zip(pred_row, label_row) if l != -100]
        for pred_row, label_row in zip(predictions, labels)
    ]

    results = seqeval.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"]
    }

# %%
model = AutoModelForTokenClassification.from_pretrained(
    "bert-base-cased",
    num_labels=len(label2id),
    id2label=id2label,
    label2id=label2id
).to('cuda' if torch.cuda.is_available() else 'cpu')

#data_collator = DataCollatorForTokenClassification(
#    tokenizer=tokenizer,
#    return_tensors="pt"
#)

args = TrainingArguments(
    output_dir="./ner-product",
    eval_strategy="no",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
    fp16=True,  # Enable mixed-precision training (faster on GPUs)
    dataloader_pin_memory=True,  # Speeds up data transfer to GPU
)

trainer = Trainer(
    model=model,
    args=args,
    train_dataset=dataset,
    eval_dataset=dataset_test,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# C:\Users\healk\AppData\Local\Temp\ipykernel_18696\298220143.py:24: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
trainer.train()
trainer.save_model("./ner-product")
tokenizer.save_pretrained("./ner-product")
# Out:
#     <div>
#
#       <progress value='3' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3/3 00:02, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ('./ner-product\\tokenizer_config.json',
#  './ner-product\\special_tokens_map.json',
#  './ner-product\\vocab.txt',
#  './ner-product\\added_tokens.json',
#  './ner-product\\tokenizer.json')

# %%
metrics = trainer.evaluate()
print(metrics)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 metrics = trainer.evaluate()
#       2 print(metrics)
#
# File c:\Users\healk\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\trainer.py:4192, in Trainer.evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    4189 # memory metrics - must set up as early as possible
#    4190 self._memory_tracker.start()
# -> 4192 eval_dataloader = self.get_eval_dataloader(eval_dataset)
#    4193 if self.is_fsdp_xla_v2_enabled:
#    4194     eval_dataloader = tpu_spmd_dataloader(eval_dataloader)
#
# File c:\Users\healk\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\trainer.py:1137, in Trainer.get_eval_dataloader(self, eval_dataset)
#    1127     return self.accelerator.prepare(self._eval_dataloaders[dataloader_key])
#    1129 eval_dataset = (
#    1130     self.eval_dataset[eval_dataset]
#    1131     if isinstance(eval_dataset, str)
#    (...)   1134     else self.eval_dataset
#    1135 )
# -> 1137 return self._get_dataloader(
#    1138     dataset=eval_dataset,
#    1139     description="Evaluation",
#    1140     batch_size=self.args.eval_batch_size,
#    1141     sampler_fn=self._get_eval_sampler,
#    1142     dataloader_key=dataloader_key,
#    1143 )
#
# File c:\Users\healk\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\trainer.py:1007, in Trainer._get_dataloader(self, dataset, description, batch_size, sampler_fn, is_training, dataloader_key)
#    1005 data_collator = self.data_collator
#    1006 if is_datasets_available() and isinstance(dataset, datasets.Dataset):
# -> 1007     dataset = self._remove_unused_columns(dataset, description=description)
#    1008 else:
#    1009     data_collator = self._get_collator_with_removed_columns(self.data_collator, description=description)
#
# File c:\Users\healk\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\trainer.py:933, in Trainer._remove_unused_columns(self, dataset, description)
#     931 columns = [k for k in signature_columns if k in dataset.column_names]
#     932 if len(columns) == 0:
# --> 933     raise ValueError(
#     934         f"No columns in the dataset match the model's forward method signature: ({', '.join(signature_columns)}). "
#     935         f"The following columns have been ignored: [{', '.join(ignored_columns)}]. "
#     936         "Please check the dataset and model. You may need to set `remove_unused_columns=False` in `TrainingArguments`."
#     937     )
#     939 if version.parse(datasets.__version__) < version.parse("1.4.0"):
#     940     dataset.set_format(
#     941         type=dataset.format["type"], columns=columns, format_kwargs=dataset.format["format_kwargs"]
#     942     )
#
# ValueError: No columns in the dataset match the model's forward method signature: (input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, label, label_ids, labels). The following columns have been ignored: []. Please check the dataset and model. You may need to set `remove_unused_columns=False` in `TrainingArguments`.

# %%
model_path = "./ner-product"  # путь к твоей дообученной модели
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForTokenClassification.from_pretrained(model_path).to('cuda' if torch.cuda.is_available() else 'cpu')

# NER pipeline
ner_pipeline = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="none")

# Получение чистого текста с веб-страницы
def extract_visible_text(url):
    try:
        r = requests.get(url, timeout=5)
        soup = BeautifulSoup(r.text, "html.parser")
        [s.decompose() for s in soup(["script", "style", "noscript"])]
        text = soup.get_text(separator='\n', strip=True)
        return text
    except Exception as e:
        return ""


def extract_products_from_text(text, min_confidence=0.45):
    ner_results = ner_pipeline(text)
    
    products = []
    current_product = []
    current_scores = []

    for token in ner_results:
        label = token['entity']
        word = token['word']
        score = token['score']
        
        if label == 'B-PRODUCT':
            if current_product:
                # Finish previous product
                avg_score = sum(current_scores) / len(current_scores)
                if avg_score >= min_confidence:
                    products.append(tokenizer.convert_tokens_to_string(current_product).strip())
                current_product = []
                current_scores = []

            current_product = [word]
            current_scores = [score]
        
        elif label == 'I-PRODUCT' and current_product:
            current_product.append(word)
            current_scores.append(score)
        
        else:
            # Outside of entity or no B-PRODUCT before
            if current_product:
                avg_score = sum(current_scores) / len(current_scores)
                if avg_score >= min_confidence:
                    products.append(tokenizer.convert_tokens_to_string(current_product).strip())
                current_product = []
                current_scores = []

    # Append last
    if current_product:
        avg_score = sum(current_scores) / len(current_scores)
        if avg_score >= min_confidence:
            products.append(tokenizer.convert_tokens_to_string(current_product).strip())
    
    return list(set(products)) 

def predict(url):
    text = extract_visible_text(url)
    if not text:
        return []

    products = extract_products_from_text(text)
    return products
# Out:
# Device set to use cuda:0

# %%
test_url = "https://www.factorybuys.com.au/products/euro-top-mattress-king"
prods = extract_products_from_text(extract_visible_text(test_url))
print(prods)    

test_text = extract_visible_text(test_url)
entities = ner_pipeline(test_text)

for ent in entities:
    print(f"{ent['word']}\t{ent['entity']}\t{ent['score']:.2f}")
# Out:
# ['##ing Tableup', 'Bed Frames Mattresses Bed', 'Double Bed Bases', '##y Cabinets', 'Queen Bed', 'Double Bed Frames', '##orage Furniture', '##room Furniture', '##y Cabinets Storage Furniture Dr', 'King Bed Bases', 'St', 'Makeup', '##ity Bed', '##E SHIPPING', 'Single Mattress Protectors', '##room Furniture Mattresses', '##ST SHIPPING', '##ing Tables Arm Chairs', 'King Mattress', 'Double Bed Linen', 'Queen Bed Head', '##ing Furniture', 'Bed Head', 'Euro Top Mattress', '##RE', 'Lightings Mattresses Dr', 'Jeweller', 'Single Bed Bases', 'Single Mattress', '##room Packages', 'Single Mattress Toppers', 'F', 'Double Bed Head', 'Super', 'Double Bed', 'Office Furniture Storage Furniture Packagesressesresses', '##ity', 'Single Bedroom Packages', '##room Packages Wardrobes', 'Din', '##ding Bed', '##room Suites', 'Double Mattress', '##ing Tables Cabinets', '##ED F', 'Single Bed', '##side Tables', 'Double Bed Heads', 'FA', 'King Bed Frames', 'ON MATTRESSES', 'Bed Framesingsresses', 'Queen Bed Bases', 'AUSTRAL', 'B', 'Shoe Storage Dr', 'Bed Frames', 'King Bed Linen', 'Factory Buys', 'Queen Bed Linen', '##side Tables Bed Frames', 'Queen Bed Frames', 'Tallboys Bed', 'King', 'Dr', '##ck Storage Furniture Bed Frames', 'Bed', 'Clothes', 'Home Furniture', 'Queen Mattress', 'King Single Mattress', 'Bed Framesresses', 'King Bed Heads', 'Shoe Storage Storage Furniture Bed Headboards', 'King Bed', 'Queen', '##ing Tables Dr', 'Living Room Furniture', 'Single Bed Linen', '##RAMES', 'Single Bed Frames', 'Tallboys', 'Bed Headboards', '##side Tables Wardrobes', '##ing Table', 'Head Bed Bases', '##room Furniture Bed', 'Ra', 'Wardrobes', 'Tallboy', 'Single Bedroom Suites', '##ess']
# Factory	B-PRODUCT	0.51
# Buy	I-PRODUCT	0.76
# ##s	I-PRODUCT	0.64
# Euro	B-PRODUCT	0.68
# Top	I-PRODUCT	0.76
# Matt	I-PRODUCT	0.92
# ##ress	I-PRODUCT	0.89
# F	B-PRODUCT	0.58
# ##RE	B-PRODUCT	0.57
# ##E	B-PRODUCT	0.73
# SH	I-PRODUCT	0.63
# ##IP	I-PRODUCT	0.56
# ##PI	I-PRODUCT	0.62
# ##NG	I-PRODUCT	0.49
# ON	B-PRODUCT	0.49
# MA	I-PRODUCT	0.50
# ##TT	I-PRODUCT	0.47
# ##RE	I-PRODUCT	0.54
# ##SS	I-PRODUCT	0.57
# ##ES	I-PRODUCT	0.59
# B	B-PRODUCT	0.56
# ##ED	B-PRODUCT	0.46
# F	I-PRODUCT	0.55
# ##RA	B-PRODUCT	0.44
# ##ME	I-PRODUCT	0.60
# ##S	I-PRODUCT	0.65
# FA	B-PRODUCT	0.58
# ##ST	B-PRODUCT	0.56
# SH	I-PRODUCT	0.69
# ##IP	I-PRODUCT	0.53
# ##PI	I-PRODUCT	0.59
# ##NG	I-PRODUCT	0.52
# AU	B-PRODUCT	0.45
# ##ST	I-PRODUCT	0.47
# ##RA	I-PRODUCT	0.44
# ##L	I-PRODUCT	0.45
# ##IA	B-PRODUCT	0.39
# W	I-PRODUCT	0.44
# ##ID	I-PRODUCT	0.37
# ##E	I-PRODUCT	0.55
# Home	B-PRODUCT	0.77
# Fu	I-PRODUCT	0.93
# ##rn	I-PRODUCT	0.89
# ##iture	I-PRODUCT	0.93
# Home	B-PRODUCT	0.79
# Fu	I-PRODUCT	0.93
# ##rn	I-PRODUCT	0.88
# ##iture	I-PRODUCT	0.93
# Bed	B-PRODUCT	0.53
# ##room	B-PRODUCT	0.71
# Fu	I-PRODUCT	0.93
# ##rn	I-PRODUCT	0.87
# ##iture	I-PRODUCT	0.90
# Matt	I-PRODUCT	0.79
# ##resses	I-PRODUCT	0.83
# Living	B-PRODUCT	0.94
# Room	I-PRODUCT	0.64
# Fu	I-PRODUCT	0.92
# ##rn	I-PRODUCT	0.87
# ##iture	I-PRODUCT	0.93
# Din	B-PRODUCT	0.88
# ##ing	B-PRODUCT	0.66
# Fu	I-PRODUCT	0.93
# ##rn	I-PRODUCT	0.87
# ##iture	I-PRODUCT	0.94
# Office	B-PRODUCT	0.87
# Fu	I-PRODUCT	0.94
# ##rn	I-PRODUCT	0.89
# ##iture	I-PRODUCT	0.93
# St	I-PRODUCT	0.59
# ##orage	I-PRODUCT	0.57
# Fu	I-PRODUCT	0.93
# ##rn	I-PRODUCT	0.88
# ##iture	I-PRODUCT	0.89
# Pack	I-PRODUCT	0.83
# ##ages	I-PRODUCT	0.88
# ##resses	I-PRODUCT	0.51
# ##resses	I-PRODUCT	0.66
# Queen	B-PRODUCT	0.81
# Matt	I-PRODUCT	0.89
# ##ress	I-PRODUCT	0.81
# Queen	B-PRODUCT	0.79
# Matt	I-PRODUCT	0.90
# ##ress	I-PRODUCT	0.83
# Queen	B-PRODUCT	0.88
# Bed	I-PRODUCT	0.61
# Fr	I-PRODUCT	0.90
# ##ame	I-PRODUCT	0.89
# ##s	I-PRODUCT	0.89
# Queen	B-PRODUCT	0.89
# Bed	I-PRODUCT	0.55
# Base	I-PRODUCT	0.92
# ##s	I-PRODUCT	0.87
# Queen	B-PRODUCT	0.88
# Bed	B-PRODUCT	0.46
# Head	I-PRODUCT	0.82
# Queen	B-PRODUCT	0.82
# Bed	I-PRODUCT	0.68
# ##room	B-PRODUCT	0.53
# Pack	I-PRODUCT	0.92
# ##ages	I-PRODUCT	0.91
# Queen	B-PRODUCT	0.87
# Bed	I-PRODUCT	0.68
# ##room	B-PRODUCT	0.58
# Suite	I-PRODUCT	0.90
# ##s	I-PRODUCT	0.89
# Queen	B-PRODUCT	0.87
# Bed	I-PRODUCT	0.53
# Line	I-PRODUCT	0.83
# ##n	I-PRODUCT	0.76
# Double	B-PRODUCT	0.82
# Matt	I-PRODUCT	0.89
# ##ress	I-PRODUCT	0.82
# Double	B-PRODUCT	0.87
# Matt	I-PRODUCT	0.89
# ##ress	I-PRODUCT	0.77
# Double	B-PRODUCT	0.91
# Bed	I-PRODUCT	0.61
# Fr	I-PRODUCT	0.88
# ##ame	I-PRODUCT	0.89
# ##s	I-PRODUCT	0.89
# Double	B-PRODUCT	0.93
# Bed	I-PRODUCT	0.56
# Base	I-PRODUCT	0.92
# ##s	I-PRODUCT	0.88
# Double	B-PRODUCT	0.93
# Bed	I-PRODUCT	0.58
# Heads	I-PRODUCT	0.90
# Double	B-PRODUCT	0.92
# Bed	I-PRODUCT	0.62
# ##room	B-PRODUCT	0.57
# Pack	I-PRODUCT	0.93
# ##ages	I-PRODUCT	0.92
# Double	B-PRODUCT	0.92
# Bed	I-PRODUCT	0.58
# ##room	B-PRODUCT	0.61
# Suite	I-PRODUCT	0.91
# ##s	I-PRODUCT	0.90
# Double	B-PRODUCT	0.92
# Bed	I-PRODUCT	0.52
# Line	I-PRODUCT	0.86
# ##n	I-PRODUCT	0.66
# King	B-PRODUCT	0.66
# Matt	I-PRODUCT	0.89
# ##ress	I-PRODUCT	0.82
# King	B-PRODUCT	0.74
# Matt	I-PRODUCT	0.88
# ##ress	I-PRODUCT	0.82
# King	B-PRODUCT	0.89
# Bed	I-PRODUCT	0.69
# Fr	I-PRODUCT	0.88
# ##ame	I-PRODUCT	0.90
# ##s	I-PRODUCT	0.90
# King	B-PRODUCT	0.91
# Bed	I-PRODUCT	0.65
# Base	I-PRODUCT	0.92
# ##s	I-PRODUCT	0.89
# King	B-PRODUCT	0.90
# Bed	I-PRODUCT	0.70
# Heads	I-PRODUCT	0.91
# King	B-PRODUCT	0.89
# Bed	I-PRODUCT	0.68
# ##room	B-PRODUCT	0.50
# Pack	I-PRODUCT	0.93
# ##ages	I-PRODUCT	0.93
# King	B-PRODUCT	0.89
# Bed	I-PRODUCT	0.71
# ##room	B-PRODUCT	0.53
# Suite	I-PRODUCT	0.91
# ##s	I-PRODUCT	0.90
# King	B-PRODUCT	0.90
# Bed	I-PRODUCT	0.63
# Line	I-PRODUCT	0.88
# ##n	I-PRODUCT	0.84
# Super	B-PRODUCT	0.77
# King	B-PRODUCT	0.49
# Matt	I-PRODUCT	0.91
# ##ress	I-PRODUCT	0.87
# King	B-PRODUCT	0.82
# Single	I-PRODUCT	0.46
# Matt	I-PRODUCT	0.92
# ##ress	I-PRODUCT	0.88
# King	B-PRODUCT	0.83
# Single	B-PRODUCT	0.48
# Matt	I-PRODUCT	0.92
# ##ress	I-PRODUCT	0.87
# King	B-PRODUCT	0.84
# Single	B-PRODUCT	0.71
# Bed	I-PRODUCT	0.72
# Fr	I-PRODUCT	0.90
# ##ame	I-PRODUCT	0.92
# ##s	I-PRODUCT	0.91
# King	B-PRODUCT	0.87
# Single	B-PRODUCT	0.74
# Bed	I-PRODUCT	0.69
# Base	I-PRODUCT	0.93
# ##s	I-PRODUCT	0.90
# King	B-PRODUCT	0.81
# Single	B-PRODUCT	0.71
# Bed	I-PRODUCT	0.69
# ##room	I-PRODUCT	0.49
# Pack	I-PRODUCT	0.94
# ##ages	I-PRODUCT	0.92
# King	B-PRODUCT	0.80
# Single	B-PRODUCT	0.67
# Bed	I-PRODUCT	0.74
# ##room	I-PRODUCT	0.45
# Suite	I-PRODUCT	0.92
# ##s	I-PRODUCT	0.92
# King	B-PRODUCT	0.87
# Single	B-PRODUCT	0.76
# Bed	I-PRODUCT	0.72
# Line	I-PRODUCT	0.88
# ##n	I-PRODUCT	0.85
# Single	B-PRODUCT	0.87
# Matt	I-PRODUCT	0.91
# ##ress	I-PRODUCT	0.79
# Single	B-PRODUCT	0.86
# Matt	I-PRODUCT	0.90
# ##ress	I-PRODUCT	0.74
# Single	B-PRODUCT	0.89
# Bed	I-PRODUCT	0.63
# Fr	I-PRODUCT	0.89
# ##ame	I-PRODUCT	0.90
# ##s	I-PRODUCT	0.91
# Single	B-PRODUCT	0.91
# Bed	I-PRODUCT	0.53
# Base	I-PRODUCT	0.92
# ##s	I-PRODUCT	0.90
# Single	B-PRODUCT	0.90
# Bed	I-PRODUCT	0.54
# ##room	B-PRODUCT	0.60
# Pack	I-PRODUCT	0.93
# ##ages	I-PRODUCT	0.91
# Single	B-PRODUCT	0.92
# Bed	I-PRODUCT	0.59
# ##room	B-PRODUCT	0.59
# Suite	I-PRODUCT	0.92
# ##s	I-PRODUCT	0.91
# Single	B-PRODUCT	0.92
# Bed	I-PRODUCT	0.53
# Line	I-PRODUCT	0.86
# ##n	I-PRODUCT	0.75
# Single	B-PRODUCT	0.87
# Matt	I-PRODUCT	0.91
# ##ress	I-PRODUCT	0.72
# Top	I-PRODUCT	0.77
# ##pers	I-PRODUCT	0.88
# Single	B-PRODUCT	0.86
# Matt	I-PRODUCT	0.89
# ##ress	I-PRODUCT	0.60
# Pro	I-PRODUCT	0.67
# ##tec	I-PRODUCT	0.40
# ##tors	I-PRODUCT	0.88
# Super	B-PRODUCT	0.76
# King	B-PRODUCT	0.48
# Matt	I-PRODUCT	0.87
# ##ress	I-PRODUCT	0.83
# Super	B-PRODUCT	0.69
# King	B-PRODUCT	0.49
# Matt	I-PRODUCT	0.88
# ##ress	I-PRODUCT	0.70
# Bed	B-PRODUCT	0.68
# Fr	I-PRODUCT	0.88
# ##ame	I-PRODUCT	0.90
# ##s	I-PRODUCT	0.90
# ##resses	I-PRODUCT	0.63
# Bed	B-PRODUCT	0.84
# ##ding	B-PRODUCT	0.74
# Bed	I-PRODUCT	0.51
# ##room	B-PRODUCT	0.78
# Pack	I-PRODUCT	0.92
# ##ages	I-PRODUCT	0.90
# Bed	B-PRODUCT	0.89
# Fr	I-PRODUCT	0.87
# ##ame	I-PRODUCT	0.88
# ##s	I-PRODUCT	0.90
# Bed	B-PRODUCT	0.85
# ##room	B-PRODUCT	0.85
# Pack	I-PRODUCT	0.93
# ##ages	I-PRODUCT	0.91
# Bed	B-PRODUCT	0.84
# ##room	B-PRODUCT	0.84
# Suite	I-PRODUCT	0.91
# ##s	I-PRODUCT	0.89
# Bed	B-PRODUCT	0.86
# ##room	B-PRODUCT	0.80
# Fu	I-PRODUCT	0.94
# ##rn	I-PRODUCT	0.85
# ##iture	I-PRODUCT	0.91
# Bed	B-PRODUCT	0.55
# ##room	B-PRODUCT	0.78
# Fu	I-PRODUCT	0.94
# ##rn	I-PRODUCT	0.83
# ##iture	I-PRODUCT	0.70
# Matt	I-PRODUCT	0.79
# ##resses	I-PRODUCT	0.75
# Bed	B-PRODUCT	0.91
# Fr	I-PRODUCT	0.87
# ##ame	I-PRODUCT	0.86
# ##s	I-PRODUCT	0.89
# Bed	B-PRODUCT	0.85
# ##room	B-PRODUCT	0.83
# Pack	I-PRODUCT	0.93
# ##ages	I-PRODUCT	0.90
# Bed	B-PRODUCT	0.84
# ##room	B-PRODUCT	0.84
# Suite	I-PRODUCT	0.91
# ##s	I-PRODUCT	0.90
# Bed	B-PRODUCT	0.89
# ##side	B-PRODUCT	0.91
# Table	I-PRODUCT	0.94
# ##s	I-PRODUCT	0.93
# Bed	B-PRODUCT	0.89
# ##side	B-PRODUCT	0.91
# Table	I-PRODUCT	0.94
# ##s	I-PRODUCT	0.92
# Tall	B-PRODUCT	0.80
# ##boy	I-PRODUCT	0.75
# ##s	I-PRODUCT	0.81
# St	B-PRODUCT	0.65
# ##orage	B-PRODUCT	0.79
# Fu	I-PRODUCT	0.94
# ##rn	I-PRODUCT	0.87
# ##iture	I-PRODUCT	0.86
# Bed	B-PRODUCT	0.66
# Fr	I-PRODUCT	0.90
# ##ame	I-PRODUCT	0.87
# ##s	I-PRODUCT	0.88
# ##ings	I-PRODUCT	0.72
# ##resses	I-PRODUCT	0.66
# Dr	B-PRODUCT	0.73
# ##ess	B-PRODUCT	0.74
# ##ing	B-PRODUCT	0.87
# Table	I-PRODUCT	0.86
# ##up	I-PRODUCT	0.56
# Van	B-PRODUCT	0.41
# ##ity	B-PRODUCT	0.78
# Bed	I-PRODUCT	0.69
# ##room	B-PRODUCT	0.62
# Pack	I-PRODUCT	0.94
# ##ages	I-PRODUCT	0.91
# Ward	I-PRODUCT	0.62
# ##robe	I-PRODUCT	0.77
# ##s	I-PRODUCT	0.85
# Ward	B-PRODUCT	0.52
# ##robe	I-PRODUCT	0.72
# ##s	I-PRODUCT	0.81
# Tall	B-PRODUCT	0.79
# ##boy	I-PRODUCT	0.71
# ##s	I-PRODUCT	0.77
# C	B-PRODUCT	0.67
# ##lot	I-PRODUCT	0.37
# ##hes	I-PRODUCT	0.69
# Ra	B-PRODUCT	0.54
# ##ck	B-PRODUCT	0.84
# St	I-PRODUCT	0.78
# ##orage	I-PRODUCT	0.65
# Fu	I-PRODUCT	0.93
# ##rn	I-PRODUCT	0.82
# ##iture	I-PRODUCT	0.88
# Bed	I-PRODUCT	0.46
# Fr	I-PRODUCT	0.67
# ##ame	I-PRODUCT	0.77
# ##s	I-PRODUCT	0.88
# Light	B-PRODUCT	0.43
# ##ings	I-PRODUCT	0.82
# Matt	I-PRODUCT	0.73
# ##resses	I-PRODUCT	0.81
# Dr	I-PRODUCT	0.53
# ##ess	B-PRODUCT	0.48
# ##ing	B-PRODUCT	0.85
# Table	I-PRODUCT	0.92
# Make	B-PRODUCT	0.68
# ##up	I-PRODUCT	0.52
# Van	B-PRODUCT	0.45
# ##ity	B-PRODUCT	0.70
# Tall	B-PRODUCT	0.88
# ##boy	I-PRODUCT	0.74
# ##s	I-PRODUCT	0.87
# Tall	B-PRODUCT	0.88
# ##boy	I-PRODUCT	0.75
# ##s	I-PRODUCT	0.88
# Bed	I-PRODUCT	0.49
# ##side	B-PRODUCT	0.61
# Table	I-PRODUCT	0.92
# ##s	I-PRODUCT	0.88
# Ward	I-PRODUCT	0.52
# ##robe	I-PRODUCT	0.73
# ##s	I-PRODUCT	0.88
# Jewel	B-PRODUCT	0.82
# ##ler	I-PRODUCT	0.37
# ##y	B-PRODUCT	0.54
# Cabinet	I-PRODUCT	0.83
# ##s	I-PRODUCT	0.89
# St	I-PRODUCT	0.62
# ##orage	I-PRODUCT	0.61
# Fu	I-PRODUCT	0.89
# ##rn	I-PRODUCT	0.79
# ##iture	I-PRODUCT	0.88
# Dr	I-PRODUCT	0.50
# ##ess	B-PRODUCT	0.47
# ##ing	B-PRODUCT	0.83
# Table	I-PRODUCT	0.91
# ##s	I-PRODUCT	0.88
# Cabinet	I-PRODUCT	0.84
# ##s	I-PRODUCT	0.88
# S	B-PRODUCT	0.49
# ##hoe	I-PRODUCT	0.55
# St	I-PRODUCT	0.65
# ##orage	I-PRODUCT	0.69
# Dr	I-PRODUCT	0.53
# ##ess	B-PRODUCT	0.56
# ##ing	B-PRODUCT	0.85
# Table	I-PRODUCT	0.92
# ##s	I-PRODUCT	0.88
# Dr	I-PRODUCT	0.45
# ##ess	B-PRODUCT	0.50
# ##ing	B-PRODUCT	0.85
# Table	I-PRODUCT	0.90
# ##s	I-PRODUCT	0.89
# Arm	I-PRODUCT	0.45
# Chair	I-PRODUCT	0.91
# ##s	I-PRODUCT	0.88
# Ward	B-PRODUCT	0.44
# ##robe	I-PRODUCT	0.73
# ##s	I-PRODUCT	0.89
# Jewel	B-PRODUCT	0.81
# ##ler	I-PRODUCT	0.43
# ##y	B-PRODUCT	0.55
# Cabinet	I-PRODUCT	0.83
# ##s	I-PRODUCT	0.89
# Tall	B-PRODUCT	0.88
# ##boy	I-PRODUCT	0.76
# ##s	I-PRODUCT	0.89
# S	B-PRODUCT	0.52
# ##hoe	I-PRODUCT	0.59
# St	I-PRODUCT	0.64
# ##orage	I-PRODUCT	0.65
# St	I-PRODUCT	0.64
# ##orage	I-PRODUCT	0.70
# Fu	I-PRODUCT	0.89
# ##rn	I-PRODUCT	0.78
# ##iture	I-PRODUCT	0.89
# Bed	I-PRODUCT	0.52
# Head	I-PRODUCT	0.43
# ##boards	I-PRODUCT	0.77
# Bed	B-PRODUCT	0.46
# Head	I-PRODUCT	0.42
# ##boards	I-PRODUCT	0.79
# Queen	B-PRODUCT	0.83
# Bed	I-PRODUCT	0.45
# Head	I-PRODUCT	0.46
# Double	B-PRODUCT	0.91
# Bed	I-PRODUCT	0.52
# Head	I-PRODUCT	0.49
# King	B-PRODUCT	0.80
# Bed	I-PRODUCT	0.52
# Head	B-PRODUCT	0.44
# Bed	I-PRODUCT	0.45
# Base	I-PRODUCT	0.72
# ##s	I-PRODUCT	0.88
# Bed	B-PRODUCT	0.46
# Fr	I-PRODUCT	0.67
# ##ame	I-PRODUCT	0.79
# ##s	I-PRODUCT	0.88
# Matt	I-PRODUCT	0.78
# ##resses	I-PRODUCT	0.84
# Bed	I-PRODUCT	0.64
# ##room	B-PRODUCT	0.65
# Fu	I-PRODUCT	0.88
# ##rn	I-PRODUCT	0.79
# ##iture	I-PRODUCT	0.88
# Bed	I-PRODUCT	0.48
# ##side	B-PRODUCT	0.58
# Table	I-PRODUCT	0.90
# ##s	I-PRODUCT	0.88
# Bed	I-PRODUCT	0.47
# Fr	I-PRODUCT	0.62
# ##ame	I-PRODUCT	0.83
# ##s	I-PRODUCT	0.89
# Tall	B-PRODUCT	0.87
# ##boy	I-PRODUCT	0.74

# %%
print(len(prods))
# Out:
# 92

# %%
# Out:
# Downloading builder script: 6.34kB [00:00, 5.01MB/s]
